# %% [markdown]
# # PHASE-1

# %%
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %%
population_df=pd.read_excel("C:\jupyter notebook\Population(2011) (1).xlsx")

# %%
population_df
# Out:
#     Rank                 State and UT  Total Population
# 0    1.0                Uttar Pradesh         199812341
# 1    2.0                  Maharashtra         112374333
# 2    3.0                        Bihar         104099452
# 3    4.0                  West bengal          91276115
# 4    5.0                Andra Pradesh          84580777
# 5    6.0               Madhya Pradesh          72626809
# 6    7.0                   Tamil Nadu          72447030
# 7    8.0                    Rajasthan          68548473
# 8    9.0                    Karnataka          61095297
# 9   10.0                      Gujarat          60439692
# 10  11.0                      Odhisha          41974218
# 11  12.0                       Kerala          33406061
# 12  13.0                    Jharkhand          32988134
# 13  14.0                        Assam          31205576
# 14  15.0                       Punjab          27743338
# 15  16.0                  Chattisgarh          25545198
# ...

# %%
population_df.head()
# Out:
#    Rank   State and UT  Total Population
# 0   1.0  Uttar Pradesh         199812341
# 1   2.0    Maharashtra         112374333
# 2   3.0          Bihar         104099452
# 3   4.0    West bengal          91276115
# 4   5.0  Andra Pradesh          84580777

# %%
population_df.tail()
# Out:
#     Rank                 State and UT  Total Population
# 31  32.0  Andaman and Nicobar Islands            380581
# 32  33.0       Dadra and Nagar Haveli            343709
# 33  34.0                Daman and Diu            243247
# 34  35.0                  Lakdhadweep             64473
# 35   NaN                        total        1211026968

# %%
population_df.columns
# Out:
# Index(['Rank', 'State and UT', 'Total Population'], dtype='object')

# %%
population_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Rank              35 non-null     float64
#  1   State and UT      36 non-null     object
#  2   Total Population  36 non-null     int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 992.0+ bytes

# %%
population_df.isnull().sum()
# Out:
# Rank                1
# State and UT        0
# Total Population    0
# dtype: int64

# %%
df=pd.read_excel("C:\jupyter notebook\literacy rate (1).xlsx")

# %%
df
# Out:
#     sl.no                 State and UT  literacy rate in 2001  \
# 0     1.0                Uttar Pradesh              56.300000
# 1     2.0                  Maharashtra              76.900000
# 2     3.0                        Bihar              47.000000
# 3     4.0                  West bengal              68.600000
# 4     5.0                Andra Pradesh              60.500000
# 5     6.0               Madhya Pradesh              63.700000
# 6     7.0                   Tamil Nadu              73.500000
# 7     8.0                    Rajasthan              60.400000
# 8     9.0                    Karnataka              66.600000
# 9    10.0                      Gujarat              70.000000
# 10   11.0                      Odhisha              63.100000
# 11   12.0                       Kerala              90.900000
# 12   13.0                    Jharkhand              53.600000
# 13   14.0                        Assam              63.300000
# ...

# %%
Area_df=pd.read_excel("C:\jupyter notebook\Area.xlsx")

# %%
Area_df
# Out:
#     sl.no                 State and UT     Area
# 0     1.0                Uttar Pradesh   240928
# 1     2.0                  Maharashtra   307713
# 2     3.0                        Bihar    94163
# 3     4.0                  West bengal    88752
# 4     5.0                Andra Pradesh   162968
# 5     6.0               Madhya Pradesh   308252
# 6     7.0                   Tamil Nadu   130058
# 7     8.0                    Rajasthan   342239
# 8     9.0                    Karnataka   191791
# 9    10.0                      Gujarat   196024
# 10   11.0                      Odhisha   155707
# 11   12.0                       Kerala    38863
# 12   13.0                    Jharkhand    79714
# 13   14.0                        Assam    78438
# 14   15.0                       Punjab    50362
# 15   16.0                  Chattisgarh   135191
# 16   17.0                      Haryana    44212
# 17   18.0                 NCT of Delhi     1490
# 18   19.0            Jammu and Kashmir    42241
# ...

# %%
Area_df.head()
# Out:
#    sl.no   State and UT    Area
# 0    1.0  Uttar Pradesh  240928
# 1    2.0    Maharashtra  307713
# 2    3.0          Bihar   94163
# 3    4.0    West bengal   88752
# 4    5.0  Andra Pradesh  162968

# %%
Area_df.tail()
# Out:
#     sl.no                 State and UT     Area
# 31   32.0  Andaman and Nicobar Islands     8249
# 32   33.0       Dadra and Nagar Haveli      491
# 33   34.0                Daman and Diu      112
# 34   35.0                  Lakdhadweep       32
# 35    NaN                        total  2995195

# %%
Area_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sl.no         35 non-null     float64
#  1   State and UT  36 non-null     object
#  2   Area          36 non-null     int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 992.0+ bytes

# %%
Area_df.describe()
# Out:
#            sl.no          Area
# count  35.000000  3.600000e+01
# mean   18.000000  1.663997e+05
# std    10.246951  4.943236e+05
# min     1.000000  3.200000e+01
# 25%     9.500000  9.926750e+03
# 50%    18.000000  5.192250e+04
# 75%    26.500000  1.403200e+05
# max    35.000000  2.995195e+06

# %%
Area_df.fillna(Area_df.mean(), inplace=True)

# %%
Area_df.dtypes
# Out:
# sl.no           float64
# State and UT     object
# Area              int64
# dtype: object

# %%
Area_df.to_csv('Area_df.csv', index=False)

# %% [markdown]
# # PHASE-4

# %%
crimes_df=pd.read_excel(r"C:\jupyter notebook\01_District_wise_crimes_committed_IPC_2001_2012.xlsx")

# %%
crimes_df
# Out:
#             STATE/UT       DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0     ANDHRA PRADESH       ADILABAD  2001     101                 60
# 1     ANDHRA PRADESH      ANANTAPUR  2001     151                125
# 2     ANDHRA PRADESH       CHITTOOR  2001     101                 57
# 3     ANDHRA PRADESH       CUDDAPAH  2001      80                 53
# 4     ANDHRA PRADESH  EAST GODAVARI  2001      82                 67
# ...              ...            ...   ...     ...                ...
# 9012     LAKSHADWEEP    LAKSHADWEEP  2012       0                  0
# 9013     LAKSHADWEEP          TOTAL  2012       0                  0
# 9014      PUDUCHERRY       KARAIKAL  2012       5                  6
# 9015      PUDUCHERRY     PUDUCHERRY  2012      24                 21
# 9016      PUDUCHERRY          TOTAL  2012      29                 27
#
#       CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# ...

# %%
crimes_df.columns
# Out:
# Index(['STATE/UT', 'DISTRICT', 'YEAR', 'MURDER', 'ATTEMPT TO MURDER',
#        'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 'RAPE', 'CUSTODIAL RAPE',
#        'OTHER RAPE', 'KIDNAPPING & ABDUCTION',
#        'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS',
#        'KIDNAPPING AND ABDUCTION OF OTHERS', 'DACOITY',
#        'PREPARATION AND ASSEMBLY FOR DACOITY', 'ROBBERY', 'BURGLARY', 'THEFT',
#        'AUTO THEFT', 'OTHER THEFT', 'RIOTS', 'CRIMINAL BREACH OF TRUST',
#        'CHEATING', 'COUNTERFIETING', 'ARSON', 'HURT/GREVIOUS HURT',
#        'DOWRY DEATHS', 'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
#        'INSULT TO MODESTY OF WOMEN', 'CRUELTY BY HUSBAND OR HIS RELATIVES',
#        'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES',
#        'CAUSING DEATH BY NEGLIGENCE', 'OTHER IPC CRIMES', 'TOTAL IPC CRIMES'],
#       dtype='object')

# %%
features=['MURDER', 'ATTEMPT TO MURDER',
       'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 'RAPE', 'CUSTODIAL RAPE',
       'OTHER RAPE', 'KIDNAPPING & ABDUCTION',
       'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS',
       'KIDNAPPING AND ABDUCTION OF OTHERS', 'DACOITY',
       'PREPARATION AND ASSEMBLY FOR DACOITY', 'ROBBERY', 'BURGLARY', 'THEFT',
       'AUTO THEFT', 'OTHER THEFT', 'RIOTS', 'CRIMINAL BREACH OF TRUST',
       'CHEATING', 'COUNTERFIETING', 'ARSON', 'HURT/GREVIOUS HURT',
       'DOWRY DEATHS', 'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
       'INSULT TO MODESTY OF WOMEN', 'CRUELTY BY HUSBAND OR HIS RELATIVES',
       'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES',
       'CAUSING DEATH BY NEGLIGENCE', 'OTHER IPC CRIMES', 'TOTAL IPC CRIMES']

# %%
from sklearn.cluster import KMeans
import numpy as np
import matplotlib.pyplot as plt

# %%
num_clusters = 3

# %%
kmeans = KMeans(n_clusters=num_clusters)

# %%
kmeans.fit(crimes_df[features])
# Out:
# KMeans(n_clusters=3)

# %%
crimes_df['Cluster'] = kmeans.labels_

# %%
cluster_dataframes = []
for cluster_label in range(num_clusters):
    cluster_df = crimes_df[crimes_df['Cluster'] == cluster_label]
    cluster_dataframes.append(cluster_df)

# %%
for i, cluster_df in enumerate(cluster_dataframes):
    print(f"Cluster {i+1}:\n")
    print(cluster_df.describe())
# Out:
# Cluster 1:
#
#               YEAR       MURDER  ATTEMPT TO MURDER  \
# count  8772.000000  8772.000000        8772.000000
# mean   2006.629959    47.515504          41.705084
# std       3.463095    48.029654          59.405004
# min    2001.000000     0.000000           0.000000
# 25%    2004.000000    18.000000          10.000000
# 50%    2007.000000    37.000000          27.000000
# 75%    2010.000000    63.000000          53.000000
# max    2012.000000  1075.000000        1474.000000
#
#        CULPABLE HOMICIDE NOT AMOUNTING TO MURDER         RAPE  CUSTODIAL RAPE  \
# count                                8772.000000  8772.000000     8772.000000
# mean                                    5.249088    28.241336        0.002964
# std                                    10.004233    31.987945        0.078408
# min                                     0.000000     0.000000        0.000000
# 25%                                     0.000000     8.000000        0.000000
# ...

# %%
cluster_df.columns
# Out:
# Index(['STATE/UT', 'DISTRICT', 'YEAR', 'MURDER', 'ATTEMPT TO MURDER',
#        'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 'RAPE', 'CUSTODIAL RAPE',
#        'OTHER RAPE', 'KIDNAPPING & ABDUCTION',
#        'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS',
#        'KIDNAPPING AND ABDUCTION OF OTHERS', 'DACOITY',
#        'PREPARATION AND ASSEMBLY FOR DACOITY', 'ROBBERY', 'BURGLARY', 'THEFT',
#        'AUTO THEFT', 'OTHER THEFT', 'RIOTS', 'CRIMINAL BREACH OF TRUST',
#        'CHEATING', 'COUNTERFIETING', 'ARSON', 'HURT/GREVIOUS HURT',
#        'DOWRY DEATHS', 'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
#        'INSULT TO MODESTY OF WOMEN', 'CRUELTY BY HUSBAND OR HIS RELATIVES',
#        'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES',
#        'CAUSING DEATH BY NEGLIGENCE', 'OTHER IPC CRIMES', 'TOTAL IPC CRIMES',
#        'Cluster'],
#       dtype='object')
